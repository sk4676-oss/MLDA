# %% [markdown]
# <a href="https://colab.research.google.com/github/sk4676-oss/MLDA/blob/main/T7_principal_component_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x,y=load_iris(return_X_y=True)
x=StandardScaler().fit_transform(x)
x_pca=PCA(n_components=2)
principalComponents=x_pca.fit_transform(x)
plt.scatter(principalComponents[:,0],principalComponents[:,1], c=y)
plt.show()
